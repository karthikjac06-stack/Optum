# %%
# %run /Workspace/Shared/Optum/Connectors

# %%
# %run /Workspace/Shared/Optum/genric_code

# %%
libraries()

# %%
adls_connector()

# %%
list_bronze_files()

# %%
#claims.csv
claims_df = read_bronze_csv("claims")

#claim_df = read_bronze_json("Claims.json")
#claims_df = spark.read.option('inferSchema', 'true').json("abfss://optum@optumadlsmde.dfs.core.windows.net/medallion/Bronze/Claims.json")

##

# %%
display(claims_df)

# %%
check_string_as_Nan(claims_df)

# %%
# Claim_Or_Rejected
# transformations specifically for claims
claims_df = claims_df.replace("NaN", None)
claims_df = claims_df.fillna({"Claim_Or_Rejected": "N"})

# %%
display(claims_df)

# %%
missing_values_count(claims_df)

# %%
write2silver(claims_df, "Claims_S.csv")
